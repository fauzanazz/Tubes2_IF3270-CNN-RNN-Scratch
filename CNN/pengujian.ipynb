# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# Normalisasi
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Split train jadi train + validation (4:1)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42
)

print("Train:", x_train.shape)
print("Validation:", x_val.shape)
print("Test:", x_test.shape)
# Out:
# Train: (40000, 32, 32, 3)
# Validation: (10000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=10,
    validation_data=(x_val, y_val),
    batch_size=64,
    verbose = 1
)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3329 - loss: 1.8217 - val_accuracy: 0.4900 - val_loss: 1.4046
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5338 - loss: 1.3059 - val_accuracy: 0.5745 - val_loss: 1.2040
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6015 - loss: 1.1394 - val_accuracy: 0.6151 - val_loss: 1.1004
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6397 - loss: 1.0310 - val_accuracy: 0.6363 - val_loss: 1.0444
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.6667 - loss: 0.9578 - val_accuracy: 0.6330 - val_loss: 1.0550
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.6839 - loss: 0.9089 - val_accuracy: 0.6561 - val_loss: 0.9852
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7036 - loss: 0.8521 - val_accuracy: 0.6613 - val_loss: 0.9685
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7139 - loss: 0.8223 - val_accuracy: 0.6728 - val_loss: 0.9501
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7300 - loss: 0.7807 - val_accuracy: 0.6703 - val_loss: 0.9518
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.7437 - loss: 0.7382 - val_accuracy: 0.6833 - val_loss: 0.9271

# %%
# Prediksi test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Flatten label test karena aslinya (10000,1)
y_test_flat = y_test.flatten()

# Hitung Macro F1
macro_f1 = f1_score(y_test_flat, y_pred_classes, average='macro')
print("Macro F1-Score on Test Set:", macro_f1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Macro F1-Score on Test Set: 0.6773323374641984

# %%
# model.save_weights("cnn_model_1.weights.h5")

model.save('models/keras_model_1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
keras_model = tf.keras.models.load_model('models/keras_model_1.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from load import load_scratch_model
from network import predict

ScratchModel = load_scratch_model(keras_model)
# Out:
# conv2d
# creating new conv layer
# max_pooling2d
# creating new max pool layer
# conv2d_1
# creating new conv layer
# max_pooling2d_1
# creating new max pool layer
# flatten
# creating new flatten layer
# dense
# creating new dense layer
# dense_1
# creating new dense layer

# %%
for layer in ScratchModel:
    print(layer.type)
# Out:
# convolution
# maxpool
# convolution
# maxpool
# flatten
# dense
# dense

# %%
preds = predict(ScratchModel,x_test)
# Out:
# mulai prediksi batch ke- 0 dari 10000
# mulai prediksi batch ke- 32 dari 10000
# mulai prediksi batch ke- 64 dari 10000
# mulai prediksi batch ke- 96 dari 10000
# mulai prediksi batch ke- 128 dari 10000
# mulai prediksi batch ke- 160 dari 10000
# mulai prediksi batch ke- 192 dari 10000
# mulai prediksi batch ke- 224 dari 10000
# mulai prediksi batch ke- 256 dari 10000
# mulai prediksi batch ke- 288 dari 10000
# mulai prediksi batch ke- 320 dari 10000
# mulai prediksi batch ke- 352 dari 10000
# mulai prediksi batch ke- 384 dari 10000
# mulai prediksi batch ke- 416 dari 10000
# mulai prediksi batch ke- 448 dari 10000
# mulai prediksi batch ke- 480 dari 10000
# mulai prediksi batch ke- 512 dari 10000
# mulai prediksi batch ke- 544 dari 10000
# mulai prediksi batch ke- 576 dari 10000
# mulai prediksi batch ke- 608 dari 10000
# mulai prediksi batch ke- 640 dari 10000
# mulai prediksi batch ke- 672 dari 10000
# mulai prediksi batch ke- 704 dari 10000
# mulai prediksi batch ke- 736 dari 10000
# mulai prediksi batch ke- 768 dari 10000
# mulai prediksi batch ke- 800 dari 10000
# mulai prediksi batch ke- 832 dari 10000
# mulai prediksi batch ke- 864 dari 10000
# mulai prediksi batch ke- 896 dari 10000
# mulai prediksi batch ke- 928 dari 10000
# mulai prediksi batch ke- 960 dari 10000
# mulai prediksi batch ke- 992 dari 10000
# mulai prediksi batch ke- 1024 dari 10000
# mulai prediksi batch ke- 1056 dari 10000
# mulai prediksi batch ke- 1088 dari 10000
# mulai prediksi batch ke- 1120 dari 10000
# mulai prediksi batch ke- 1152 dari 10000
# mulai prediksi batch ke- 1184 dari 10000
# mulai prediksi batch ke- 1216 dari 10000
# mulai prediksi batch ke- 1248 dari 10000
# mulai prediksi batch ke- 1280 dari 10000
# mulai prediksi batch ke- 1312 dari 10000
# mulai prediksi batch ke- 1344 dari 10000
# mulai prediksi batch ke- 1376 dari 10000
# mulai prediksi batch ke- 1408 dari 10000
# mulai prediksi batch ke- 1440 dari 10000
# mulai prediksi batch ke- 1472 dari 10000
# mulai prediksi batch ke- 1504 dari 10000
# mulai prediksi batch ke- 1536 dari 10000
# mulai prediksi batch ke- 1568 dari 10000
# mulai prediksi batch ke- 1600 dari 10000
# mulai prediksi batch ke- 1632 dari 10000
# mulai prediksi batch ke- 1664 dari 10000
# mulai prediksi batch ke- 1696 dari 10000
# mulai prediksi batch ke- 1728 dari 10000
# mulai prediksi batch ke- 1760 dari 10000
# mulai prediksi batch ke- 1792 dari 10000
# mulai prediksi batch ke- 1824 dari 10000
# mulai prediksi batch ke- 1856 dari 10000
# mulai prediksi batch ke- 1888 dari 10000
# mulai prediksi batch ke- 1920 dari 10000
# mulai prediksi batch ke- 1952 dari 10000
# mulai prediksi batch ke- 1984 dari 10000
# mulai prediksi batch ke- 2016 dari 10000
# mulai prediksi batch ke- 2048 dari 10000
# mulai prediksi batch ke- 2080 dari 10000
# mulai prediksi batch ke- 2112 dari 10000
# mulai prediksi batch ke- 2144 dari 10000
# mulai prediksi batch ke- 2176 dari 10000
# mulai prediksi batch ke- 2208 dari 10000
# mulai prediksi batch ke- 2240 dari 10000
# mulai prediksi batch ke- 2272 dari 10000
# mulai prediksi batch ke- 2304 dari 10000
# mulai prediksi batch ke- 2336 dari 10000
# mulai prediksi batch ke- 2368 dari 10000
# mulai prediksi batch ke- 2400 dari 10000
# mulai prediksi batch ke- 2432 dari 10000
# mulai prediksi batch ke- 2464 dari 10000
# mulai prediksi batch ke- 2496 dari 10000
# mulai prediksi batch ke- 2528 dari 10000
# mulai prediksi batch ke- 2560 dari 10000
# mulai prediksi batch ke- 2592 dari 10000
# mulai prediksi batch ke- 2624 dari 10000
# mulai prediksi batch ke- 2656 dari 10000
# mulai prediksi batch ke- 2688 dari 10000
# mulai prediksi batch ke- 2720 dari 10000
# mulai prediksi batch ke- 2752 dari 10000
# mulai prediksi batch ke- 2784 dari 10000
# mulai prediksi batch ke- 2816 dari 10000
# mulai prediksi batch ke- 2848 dari 10000
# mulai prediksi batch ke- 2880 dari 10000
# mulai prediksi batch ke- 2912 dari 10000
# mulai prediksi batch ke- 2944 dari 10000
# mulai prediksi batch ke- 2976 dari 10000
# mulai prediksi batch ke- 3008 dari 10000
# mulai prediksi batch ke- 3040 dari 10000
# mulai prediksi batch ke- 3072 dari 10000
# mulai prediksi batch ke- 3104 dari 10000
# mulai prediksi batch ke- 3136 dari 10000
# mulai prediksi batch ke- 3168 dari 10000
# mulai prediksi batch ke- 3200 dari 10000
# mulai prediksi batch ke- 3232 dari 10000
# mulai prediksi batch ke- 3264 dari 10000
# mulai prediksi batch ke- 3296 dari 10000
# mulai prediksi batch ke- 3328 dari 10000
# mulai prediksi batch ke- 3360 dari 10000
# mulai prediksi batch ke- 3392 dari 10000
# mulai prediksi batch ke- 3424 dari 10000
# mulai prediksi batch ke- 3456 dari 10000
# mulai prediksi batch ke- 3488 dari 10000
# mulai prediksi batch ke- 3520 dari 10000
# mulai prediksi batch ke- 3552 dari 10000
# mulai prediksi batch ke- 3584 dari 10000
# mulai prediksi batch ke- 3616 dari 10000
# mulai prediksi batch ke- 3648 dari 10000
# mulai prediksi batch ke- 3680 dari 10000
# mulai prediksi batch ke- 3712 dari 10000
# mulai prediksi batch ke- 3744 dari 10000
# mulai prediksi batch ke- 3776 dari 10000
# mulai prediksi batch ke- 3808 dari 10000
# mulai prediksi batch ke- 3840 dari 10000
# mulai prediksi batch ke- 3872 dari 10000
# mulai prediksi batch ke- 3904 dari 10000
# mulai prediksi batch ke- 3936 dari 10000
# mulai prediksi batch ke- 3968 dari 10000
# mulai prediksi batch ke- 4000 dari 10000
# mulai prediksi batch ke- 4032 dari 10000
# mulai prediksi batch ke- 4064 dari 10000
# mulai prediksi batch ke- 4096 dari 10000
# mulai prediksi batch ke- 4128 dari 10000
# mulai prediksi batch ke- 4160 dari 10000
# mulai prediksi batch ke- 4192 dari 10000
# mulai prediksi batch ke- 4224 dari 10000
# mulai prediksi batch ke- 4256 dari 10000
# mulai prediksi batch ke- 4288 dari 10000
# mulai prediksi batch ke- 4320 dari 10000
# mulai prediksi batch ke- 4352 dari 10000
# mulai prediksi batch ke- 4384 dari 10000
# mulai prediksi batch ke- 4416 dari 10000
# mulai prediksi batch ke- 4448 dari 10000
# mulai prediksi batch ke- 4480 dari 10000
# mulai prediksi batch ke- 4512 dari 10000
# mulai prediksi batch ke- 4544 dari 10000
# mulai prediksi batch ke- 4576 dari 10000
# mulai prediksi batch ke- 4608 dari 10000
# mulai prediksi batch ke- 4640 dari 10000
# mulai prediksi batch ke- 4672 dari 10000
# mulai prediksi batch ke- 4704 dari 10000
# mulai prediksi batch ke- 4736 dari 10000
# mulai prediksi batch ke- 4768 dari 10000
# mulai prediksi batch ke- 4800 dari 10000
# mulai prediksi batch ke- 4832 dari 10000
# mulai prediksi batch ke- 4864 dari 10000
# mulai prediksi batch ke- 4896 dari 10000
# mulai prediksi batch ke- 4928 dari 10000
# mulai prediksi batch ke- 4960 dari 10000
# mulai prediksi batch ke- 4992 dari 10000
# mulai prediksi batch ke- 5024 dari 10000
# mulai prediksi batch ke- 5056 dari 10000
# mulai prediksi batch ke- 5088 dari 10000
# mulai prediksi batch ke- 5120 dari 10000
# mulai prediksi batch ke- 5152 dari 10000
# mulai prediksi batch ke- 5184 dari 10000
# mulai prediksi batch ke- 5216 dari 10000
# mulai prediksi batch ke- 5248 dari 10000
# mulai prediksi batch ke- 5280 dari 10000
# mulai prediksi batch ke- 5312 dari 10000
# mulai prediksi batch ke- 5344 dari 10000
# mulai prediksi batch ke- 5376 dari 10000
# mulai prediksi batch ke- 5408 dari 10000
# mulai prediksi batch ke- 5440 dari 10000
# mulai prediksi batch ke- 5472 dari 10000
# mulai prediksi batch ke- 5504 dari 10000
# mulai prediksi batch ke- 5536 dari 10000
# mulai prediksi batch ke- 5568 dari 10000
# mulai prediksi batch ke- 5600 dari 10000
# mulai prediksi batch ke- 5632 dari 10000
# mulai prediksi batch ke- 5664 dari 10000
# mulai prediksi batch ke- 5696 dari 10000
# mulai prediksi batch ke- 5728 dari 10000
# mulai prediksi batch ke- 5760 dari 10000
# mulai prediksi batch ke- 5792 dari 10000
# mulai prediksi batch ke- 5824 dari 10000
# mulai prediksi batch ke- 5856 dari 10000
# mulai prediksi batch ke- 5888 dari 10000
# mulai prediksi batch ke- 5920 dari 10000
# mulai prediksi batch ke- 5952 dari 10000
# mulai prediksi batch ke- 5984 dari 10000
# mulai prediksi batch ke- 6016 dari 10000
# mulai prediksi batch ke- 6048 dari 10000
# mulai prediksi batch ke- 6080 dari 10000
# mulai prediksi batch ke- 6112 dari 10000
# mulai prediksi batch ke- 6144 dari 10000
# mulai prediksi batch ke- 6176 dari 10000
# mulai prediksi batch ke- 6208 dari 10000
# mulai prediksi batch ke- 6240 dari 10000
# mulai prediksi batch ke- 6272 dari 10000
# mulai prediksi batch ke- 6304 dari 10000
# mulai prediksi batch ke- 6336 dari 10000
# mulai prediksi batch ke- 6368 dari 10000
# mulai prediksi batch ke- 6400 dari 10000
# mulai prediksi batch ke- 6432 dari 10000
# mulai prediksi batch ke- 6464 dari 10000
# mulai prediksi batch ke- 6496 dari 10000
# mulai prediksi batch ke- 6528 dari 10000
# mulai prediksi batch ke- 6560 dari 10000
# mulai prediksi batch ke- 6592 dari 10000
# mulai prediksi batch ke- 6624 dari 10000
# mulai prediksi batch ke- 6656 dari 10000
# mulai prediksi batch ke- 6688 dari 10000
# mulai prediksi batch ke- 6720 dari 10000
# mulai prediksi batch ke- 6752 dari 10000
# mulai prediksi batch ke- 6784 dari 10000
# mulai prediksi batch ke- 6816 dari 10000
# mulai prediksi batch ke- 6848 dari 10000
# mulai prediksi batch ke- 6880 dari 10000
# mulai prediksi batch ke- 6912 dari 10000
# mulai prediksi batch ke- 6944 dari 10000
# mulai prediksi batch ke- 6976 dari 10000
# mulai prediksi batch ke- 7008 dari 10000
# mulai prediksi batch ke- 7040 dari 10000
# mulai prediksi batch ke- 7072 dari 10000
# mulai prediksi batch ke- 7104 dari 10000
# mulai prediksi batch ke- 7136 dari 10000
# mulai prediksi batch ke- 7168 dari 10000
# mulai prediksi batch ke- 7200 dari 10000
# mulai prediksi batch ke- 7232 dari 10000
# mulai prediksi batch ke- 7264 dari 10000
# mulai prediksi batch ke- 7296 dari 10000
# mulai prediksi batch ke- 7328 dari 10000
# mulai prediksi batch ke- 7360 dari 10000
# mulai prediksi batch ke- 7392 dari 10000
# mulai prediksi batch ke- 7424 dari 10000
# mulai prediksi batch ke- 7456 dari 10000
# mulai prediksi batch ke- 7488 dari 10000
# mulai prediksi batch ke- 7520 dari 10000
# mulai prediksi batch ke- 7552 dari 10000
# mulai prediksi batch ke- 7584 dari 10000
# mulai prediksi batch ke- 7616 dari 10000
# mulai prediksi batch ke- 7648 dari 10000
# mulai prediksi batch ke- 7680 dari 10000
# mulai prediksi batch ke- 7712 dari 10000
# mulai prediksi batch ke- 7744 dari 10000
# mulai prediksi batch ke- 7776 dari 10000
# mulai prediksi batch ke- 7808 dari 10000
# mulai prediksi batch ke- 7840 dari 10000
# mulai prediksi batch ke- 7872 dari 10000
# mulai prediksi batch ke- 7904 dari 10000
# mulai prediksi batch ke- 7936 dari 10000
# mulai prediksi batch ke- 7968 dari 10000
# mulai prediksi batch ke- 8000 dari 10000
# mulai prediksi batch ke- 8032 dari 10000
# mulai prediksi batch ke- 8064 dari 10000
# mulai prediksi batch ke- 8096 dari 10000
# mulai prediksi batch ke- 8128 dari 10000
# mulai prediksi batch ke- 8160 dari 10000
# mulai prediksi batch ke- 8192 dari 10000
# mulai prediksi batch ke- 8224 dari 10000
# mulai prediksi batch ke- 8256 dari 10000
# mulai prediksi batch ke- 8288 dari 10000
# mulai prediksi batch ke- 8320 dari 10000
# mulai prediksi batch ke- 8352 dari 10000
# mulai prediksi batch ke- 8384 dari 10000
# mulai prediksi batch ke- 8416 dari 10000
# mulai prediksi batch ke- 8448 dari 10000
# mulai prediksi batch ke- 8480 dari 10000
# mulai prediksi batch ke- 8512 dari 10000
# mulai prediksi batch ke- 8544 dari 10000
# mulai prediksi batch ke- 8576 dari 10000
# mulai prediksi batch ke- 8608 dari 10000
# mulai prediksi batch ke- 8640 dari 10000
# mulai prediksi batch ke- 8672 dari 10000
# mulai prediksi batch ke- 8704 dari 10000
# mulai prediksi batch ke- 8736 dari 10000
# mulai prediksi batch ke- 8768 dari 10000
# mulai prediksi batch ke- 8800 dari 10000
# mulai prediksi batch ke- 8832 dari 10000
# mulai prediksi batch ke- 8864 dari 10000
# mulai prediksi batch ke- 8896 dari 10000
# mulai prediksi batch ke- 8928 dari 10000
# mulai prediksi batch ke- 8960 dari 10000
# mulai prediksi batch ke- 8992 dari 10000
# mulai prediksi batch ke- 9024 dari 10000
# mulai prediksi batch ke- 9056 dari 10000
# mulai prediksi batch ke- 9088 dari 10000
# mulai prediksi batch ke- 9120 dari 10000
# mulai prediksi batch ke- 9152 dari 10000
# mulai prediksi batch ke- 9184 dari 10000
# mulai prediksi batch ke- 9216 dari 10000
# mulai prediksi batch ke- 9248 dari 10000
# mulai prediksi batch ke- 9280 dari 10000
# mulai prediksi batch ke- 9312 dari 10000
# mulai prediksi batch ke- 9344 dari 10000
# mulai prediksi batch ke- 9376 dari 10000
# mulai prediksi batch ke- 9408 dari 10000
# mulai prediksi batch ke- 9440 dari 10000
# mulai prediksi batch ke- 9472 dari 10000
# mulai prediksi batch ke- 9504 dari 10000
# mulai prediksi batch ke- 9536 dari 10000
# mulai prediksi batch ke- 9568 dari 10000
# mulai prediksi batch ke- 9600 dari 10000
# mulai prediksi batch ke- 9632 dari 10000
# mulai prediksi batch ke- 9664 dari 10000
# mulai prediksi batch ke- 9696 dari 10000
# mulai prediksi batch ke- 9728 dari 10000
# mulai prediksi batch ke- 9760 dari 10000
# mulai prediksi batch ke- 9792 dari 10000
# mulai prediksi batch ke- 9824 dari 10000
# mulai prediksi batch ke- 9856 dari 10000
# mulai prediksi batch ke- 9888 dari 10000
# mulai prediksi batch ke- 9920 dari 10000
# mulai prediksi batch ke- 9952 dari 10000
# mulai prediksi batch ke- 9984 dari 10000

# %%
preds_classes = np.argmax(preds, axis=1)

# Flatten label test karena aslinya (10000,1)
y_test_flat = y_test.flatten()

# Hitung Macro F1
scratch_macro_f1 = f1_score(y_test_flat, preds_classes, average='macro')
print("Macro F1-Score on Test Set:", scratch_macro_f1)
# Out:
# Macro F1-Score on Test Set: 0.6773323374641984
