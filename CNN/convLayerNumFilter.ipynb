# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# Normalisasi
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Split train jadi train + validation (4:1)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42
)

print("Train:", x_train.shape)
print("Validation:", x_val.shape)
print("Test:", x_test.shape)
# Out:
# Train: (40000, 32, 32, 3)
# Validation: (10000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(32, (3, 3), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Flatten())
model1.add(layers.Dense(32, activation='relu'))
model1.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(64, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Flatten())
model2.add(layers.Dense(64, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model3 = models.Sequential()
model3.add(layers.Conv2D(128, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Flatten())
model3.add(layers.Dense(128, activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas
model3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
def train_model(model):
    history = model.fit(
        x_train, y_train,
        epochs=20,
        validation_data=(x_val, y_val),
        batch_size=64,
        verbose = 1
    )
    return history

# %%
history1 = train_model(model1)
history2 = train_model(model2)
history3 = train_model(model3)
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.2003 - loss: 2.0665 - val_accuracy: 0.3882 - val_loss: 1.6355
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.3989 - loss: 1.6007 - val_accuracy: 0.4407 - val_loss: 1.5008
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4452 - loss: 1.4967 - val_accuracy: 0.4558 - val_loss: 1.4726
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.4724 - loss: 1.4227 - val_accuracy: 0.4739 - val_loss: 1.4483
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.4920 - loss: 1.3726 - val_accuracy: 0.4927 - val_loss: 1.3785
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5036 - loss: 1.3455 - val_accuracy: 0.5037 - val_loss: 1.3477
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5166 - loss: 1.3034 - val_accuracy: 0.5025 - val_loss: 1.3484
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5265 - loss: 1.2725 - val_accuracy: 0.5045 - val_loss: 1.3390
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5440 - loss: 1.2391 - val_accuracy: 0.5305 - val_loss: 1.2813
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5609 - loss: 1.1936 - val_accuracy: 0.5435 - val_loss: 1.2313
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5782 - loss: 1.1520 - val_accuracy: 0.5627 - val_loss: 1.2094
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5834 - loss: 1.1252 - val_accuracy: 0.5658 - val_loss: 1.2005
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.5984 - loss: 1.0997 - val_accuracy: 0.5473 - val_loss: 1.2237
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6074 - loss: 1.0650 - val_accuracy: 0.5732 - val_loss: 1.1729
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6063 - loss: 1.0597 - val_accuracy: 0.5839 - val_loss: 1.1524
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6187 - loss: 1.0428 - val_accuracy: 0.5843 - val_loss: 1.1545
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6270 - loss: 1.0144 - val_accuracy: 0.5709 - val_loss: 1.1848
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6262 - loss: 1.0099 - val_accuracy: 0.5865 - val_loss: 1.1555
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6316 - loss: 1.0038 - val_accuracy: 0.5746 - val_loss: 1.1907
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.6380 - loss: 0.9827 - val_accuracy: 0.5853 - val_loss: 1.1563
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 21ms/step - accuracy: 0.3722 - loss: 1.7556 - val_accuracy: 0.5394 - val_loss: 1.3354
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.5562 - loss: 1.2617 - val_accuracy: 0.5798 - val_loss: 1.2034
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.6048 - loss: 1.1266 - val_accuracy: 0.6013 - val_loss: 1.1486
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6400 - loss: 1.0252 - val_accuracy: 0.6328 - val_loss: 1.0712
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6669 - loss: 0.9697 - val_accuracy: 0.6132 - val_loss: 1.1141
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6830 - loss: 0.9134 - val_accuracy: 0.6428 - val_loss: 1.0472
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7012 - loss: 0.8561 - val_accuracy: 0.6371 - val_loss: 1.0464
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7159 - loss: 0.8129 - val_accuracy: 0.6483 - val_loss: 1.0412
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7320 - loss: 0.7726 - val_accuracy: 0.6490 - val_loss: 1.0473
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - accuracy: 0.7478 - loss: 0.7283 - val_accuracy: 0.6465 - val_loss: 1.0487
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7612 - loss: 0.6926 - val_accuracy: 0.6588 - val_loss: 1.0449
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7758 - loss: 0.6533 - val_accuracy: 0.6449 - val_loss: 1.0911
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7848 - loss: 0.6220 - val_accuracy: 0.6581 - val_loss: 1.0667
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.7982 - loss: 0.5778 - val_accuracy: 0.6581 - val_loss: 1.0735
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8118 - loss: 0.5471 - val_accuracy: 0.6373 - val_loss: 1.1742
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.8266 - loss: 0.5096 - val_accuracy: 0.6455 - val_loss: 1.1729
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.8339 - loss: 0.4834 - val_accuracy: 0.6433 - val_loss: 1.2080
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8461 - loss: 0.4524 - val_accuracy: 0.6464 - val_loss: 1.2035
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8596 - loss: 0.4153 - val_accuracy: 0.6366 - val_loss: 1.3013
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.8656 - loss: 0.3932 - val_accuracy: 0.6396 - val_loss: 1.3018
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 56ms/step - accuracy: 0.3707 - loss: 1.7624 - val_accuracy: 0.5257 - val_loss: 1.3243
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.5787 - loss: 1.2075 - val_accuracy: 0.5967 - val_loss: 1.1682
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.6300 - loss: 1.0586 - val_accuracy: 0.6249 - val_loss: 1.0816
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.6754 - loss: 0.9304 - val_accuracy: 0.6435 - val_loss: 1.0345
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 52ms/step - accuracy: 0.7089 - loss: 0.8382 - val_accuracy: 0.6482 - val_loss: 1.0247
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.7336 - loss: 0.7659 - val_accuracy: 0.6567 - val_loss: 1.0215
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.7720 - loss: 0.6588 - val_accuracy: 0.6477 - val_loss: 1.0757
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7942 - loss: 0.5950 - val_accuracy: 0.6648 - val_loss: 1.0287
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8174 - loss: 0.5384 - val_accuracy: 0.6592 - val_loss: 1.1014
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 38s 60ms/step - accuracy: 0.8483 - loss: 0.4495 - val_accuracy: 0.6413 - val_loss: 1.1776
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8679 - loss: 0.3935 - val_accuracy: 0.6559 - val_loss: 1.1899
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 52ms/step - accuracy: 0.8915 - loss: 0.3308 - val_accuracy: 0.6466 - val_loss: 1.2592
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.9096 - loss: 0.2811 - val_accuracy: 0.6498 - val_loss: 1.3188
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.9266 - loss: 0.2329 - val_accuracy: 0.6326 - val_loss: 1.4557
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 52ms/step - accuracy: 0.9379 - loss: 0.1988 - val_accuracy: 0.6351 - val_loss: 1.5581
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9479 - loss: 0.1720 - val_accuracy: 0.6385 - val_loss: 1.6033
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.9585 - loss: 0.1402 - val_accuracy: 0.6381 - val_loss: 1.7820
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.9634 - loss: 0.1229 - val_accuracy: 0.6391 - val_loss: 1.8540
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - accuracy: 0.9663 - loss: 0.1137 - val_accuracy: 0.6382 - val_loss: 1.8887
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 35s 56ms/step - accuracy: 0.9724 - loss: 0.0945 - val_accuracy: 0.6385 - val_loss: 1.9706

# %%
# Prediksi test set
def predict_with(model):

    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Flatten label test karena aslinya (10000,1)
    y_test_flat = y_test.flatten()

    # Hitung Macro F1
    macro_f1 = f1_score(y_test_flat, y_pred_classes, average='macro')
    print("Macro F1-Score on Test Set:", macro_f1)

# %%
predict_with(model1)
predict_with(model2)
predict_with(model3)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Macro F1-Score on Test Set: 0.5817859396133345
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Macro F1-Score on Test Set: 0.6327341050742965
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Macro F1-Score on Test Set: 0.6305663193832487

# %%
import matplotlib.pyplot as plt

def plot_loss_histories(histories, labels):
    """Membuat grafik training dan validation loss dari beberapa riwayat pelatihan.

    Args:
        histories (list): Daftar objek History (hasil dari model.fit).
        labels (list): Daftar label yang sesuai untuk setiap riwayat.

    Returns:
        None (menampilkan grafik)
    """

    # Grafik Training Loss
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, grafik pertama
    for history, label in zip(histories, labels):
        plt.plot(history.history['loss'], label=label)
    plt.title('Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Grafik Validation Loss
    plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, grafik kedua
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_loss'], label=label)
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()  # Menyesuaikan tata letak agar tidak tumpang tindih
    plt.show()

# %%
plot_loss_histories([history1,history2,history3],['Model1','Model2','Model3'])
