# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# Normalisasi
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Split train jadi train + validation (4:1)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42
)

print("Train:", x_train.shape)
print("Validation:", x_val.shape)
print("Test:", x_test.shape)
# Out:
# Train: (40000, 32, 32, 3)
# Validation: (10000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(16, (3, 3), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Flatten())
model1.add(layers.Dense(16, activation='relu'))
model1.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(16, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Conv2D(16, (3, 3), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Flatten())
model2.add(layers.Dense(16, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model3 = models.Sequential()
model3.add(layers.Conv2D(16, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(16, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(16, (3, 3), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Flatten())
model3.add(layers.Dense(16, activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas
model3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
def train_model(model):
    history = model.fit(
        x_train, y_train,
        epochs=20,
        validation_data=(x_val, y_val),
        batch_size=64,
        verbose = 1
    )
    return history

# %%
history1 = train_model(model1)
history2 = train_model(model2)
history3 = train_model(model3)
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1482 - loss: 2.2022 - val_accuracy: 0.1996 - val_loss: 1.9251
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2324 - loss: 1.8709 - val_accuracy: 0.2773 - val_loss: 1.7812
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2972 - loss: 1.7708 - val_accuracy: 0.3180 - val_loss: 1.7277
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3301 - loss: 1.7045 - val_accuracy: 0.3847 - val_loss: 1.6200
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3980 - loss: 1.5884 - val_accuracy: 0.3975 - val_loss: 1.5996
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4158 - loss: 1.5476 - val_accuracy: 0.4176 - val_loss: 1.5444
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4246 - loss: 1.5171 - val_accuracy: 0.4152 - val_loss: 1.5343
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4371 - loss: 1.4840 - val_accuracy: 0.4333 - val_loss: 1.4939
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4437 - loss: 1.4566 - val_accuracy: 0.4333 - val_loss: 1.4960
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4487 - loss: 1.4376 - val_accuracy: 0.4399 - val_loss: 1.4727
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4501 - loss: 1.4319 - val_accuracy: 0.4515 - val_loss: 1.4533
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4676 - loss: 1.4090 - val_accuracy: 0.4384 - val_loss: 1.4632
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4649 - loss: 1.4065 - val_accuracy: 0.4572 - val_loss: 1.4339
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4774 - loss: 1.3772 - val_accuracy: 0.4442 - val_loss: 1.4500
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4758 - loss: 1.3713 - val_accuracy: 0.4523 - val_loss: 1.4440
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4846 - loss: 1.3605 - val_accuracy: 0.4513 - val_loss: 1.4292
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4842 - loss: 1.3536 - val_accuracy: 0.4627 - val_loss: 1.4216
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4867 - loss: 1.3424 - val_accuracy: 0.4542 - val_loss: 1.4350
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4965 - loss: 1.3273 - val_accuracy: 0.4671 - val_loss: 1.4021
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4952 - loss: 1.3260 - val_accuracy: 0.4682 - val_loss: 1.4011
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.2447 - loss: 2.0207 - val_accuracy: 0.4022 - val_loss: 1.6077
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4321 - loss: 1.5518 - val_accuracy: 0.4762 - val_loss: 1.4323
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4982 - loss: 1.4000 - val_accuracy: 0.5114 - val_loss: 1.3512
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5319 - loss: 1.3225 - val_accuracy: 0.5320 - val_loss: 1.2971
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5538 - loss: 1.2584 - val_accuracy: 0.5706 - val_loss: 1.2181
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5719 - loss: 1.2049 - val_accuracy: 0.5729 - val_loss: 1.2033
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5856 - loss: 1.1787 - val_accuracy: 0.5657 - val_loss: 1.2345
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5936 - loss: 1.1523 - val_accuracy: 0.5962 - val_loss: 1.1533
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6075 - loss: 1.1227 - val_accuracy: 0.6024 - val_loss: 1.1300
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6116 - loss: 1.1107 - val_accuracy: 0.6075 - val_loss: 1.1155
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6218 - loss: 1.0781 - val_accuracy: 0.5984 - val_loss: 1.1615
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6254 - loss: 1.0700 - val_accuracy: 0.6098 - val_loss: 1.1190
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6294 - loss: 1.0538 - val_accuracy: 0.6251 - val_loss: 1.0728
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6375 - loss: 1.0286 - val_accuracy: 0.6173 - val_loss: 1.0933
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6407 - loss: 1.0120 - val_accuracy: 0.6238 - val_loss: 1.0763
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6487 - loss: 1.0098 - val_accuracy: 0.6109 - val_loss: 1.1096
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6467 - loss: 0.9958 - val_accuracy: 0.6264 - val_loss: 1.0667
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6510 - loss: 0.9908 - val_accuracy: 0.6364 - val_loss: 1.0411
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6580 - loss: 0.9753 - val_accuracy: 0.6318 - val_loss: 1.0528
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.6581 - loss: 0.9784 - val_accuracy: 0.6261 - val_loss: 1.0592
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.2153 - loss: 2.0843 - val_accuracy: 0.3552 - val_loss: 1.7330
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.3690 - loss: 1.6985 - val_accuracy: 0.3950 - val_loss: 1.6053
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4095 - loss: 1.5947 - val_accuracy: 0.4314 - val_loss: 1.5326
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4423 - loss: 1.5176 - val_accuracy: 0.4483 - val_loss: 1.4813
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4665 - loss: 1.4624 - val_accuracy: 0.4755 - val_loss: 1.4270
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.4877 - loss: 1.4078 - val_accuracy: 0.4893 - val_loss: 1.3886
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4963 - loss: 1.3875 - val_accuracy: 0.4996 - val_loss: 1.3685
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5093 - loss: 1.3473 - val_accuracy: 0.5056 - val_loss: 1.3554
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.5236 - loss: 1.3143 - val_accuracy: 0.5167 - val_loss: 1.3225
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5325 - loss: 1.2934 - val_accuracy: 0.5254 - val_loss: 1.2912
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.5455 - loss: 1.2504 - val_accuracy: 0.5318 - val_loss: 1.2946
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5542 - loss: 1.2423 - val_accuracy: 0.5407 - val_loss: 1.2581
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5606 - loss: 1.2253 - val_accuracy: 0.5415 - val_loss: 1.2691
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5669 - loss: 1.2007 - val_accuracy: 0.5548 - val_loss: 1.2339
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5708 - loss: 1.1993 - val_accuracy: 0.5587 - val_loss: 1.2217
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5857 - loss: 1.1661 - val_accuracy: 0.5721 - val_loss: 1.1950
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5900 - loss: 1.1532 - val_accuracy: 0.5649 - val_loss: 1.2037
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5922 - loss: 1.1446 - val_accuracy: 0.5740 - val_loss: 1.1791
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5933 - loss: 1.1343 - val_accuracy: 0.5832 - val_loss: 1.1681
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.6033 - loss: 1.1216 - val_accuracy: 0.5783 - val_loss: 1.1690

# %%
# Prediksi test set
def predict_with(model):

    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Flatten label test karena aslinya (10000,1)
    y_test_flat = y_test.flatten()

    # Hitung Macro F1
    macro_f1 = f1_score(y_test_flat, y_pred_classes, average='macro')
    print("Macro F1-Score on Test Set:", macro_f1)

# %%
predict_with(model1)
predict_with(model2)
predict_with(model3)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Macro F1-Score on Test Set: 0.4702511451885433
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Macro F1-Score on Test Set: 0.6150259309252166
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Macro F1-Score on Test Set: 0.5805679943317058

# %%
import matplotlib.pyplot as plt

def plot_loss_histories(histories, labels):
    """Membuat grafik training dan validation loss dari beberapa riwayat pelatihan.

    Args:
        histories (list): Daftar objek History (hasil dari model.fit).
        labels (list): Daftar label yang sesuai untuk setiap riwayat.

    Returns:
        None (menampilkan grafik)
    """

    # Grafik Training Loss
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, grafik pertama
    for history, label in zip(histories, labels):
        plt.plot(history.history['loss'], label=label)
    plt.title('Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Grafik Validation Loss
    plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, grafik kedua
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_loss'], label=label)
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()  # Menyesuaikan tata letak agar tidak tumpang tindih
    plt.show()

# Contoh penggunaan:
# Asumsikan Anda memiliki beberapa model yang sudah dilatih dan
# disimpan dalam variabel history1, history2, dll.

# history1 = model1.fit(...)  # Contoh
# history2 = model2.fit(...)
# ...

# plot_loss_histories([history1, history2], ['Model 1', 'Model 2'])

# %%
plot_loss_histories([history1,history2,history3],['Model1','Model2','Model3'])

# %%
model1.save('../models/test1_model_1.h5')
model2.save('../models/test1_model_2.h5')
model3.save('../models/test1_model_3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import sys
import os

dir_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if dir_path not in sys.path:
    sys.path.insert(0, dir_path)

try:
    from implementation import load
    from implementation import network
    print("Successfully imported 'load' and 'network' from the 'modules' package.")

except ImportError as e:
    print(f"Error importing modules: {e}")
# Out:
# Successfully imported 'load' and 'network' from the 'modules' package.

# %%
ScratchModel1 = load.load_scratch_model('../models/test1_model_1.h5')
ScratchModel2= load.load_scratch_model('../models/test1_model_2.h5')
ScratchModel3 = load.load_scratch_model('../models/test1_model_3.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# conv2d_6
# creating new conv layer
# max_pooling2d_3
# creating new max pool layer
# flatten_3
# creating new flatten layer
# dense_6
# creating new dense layer
# dense_7
# creating new dense layer
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# conv2d_7
# creating new conv layer
# max_pooling2d_4
# creating new max pool layer
# conv2d_8
# creating new conv layer
# max_pooling2d_5
# creating new max pool layer
# flatten_4
# creating new flatten layer
# dense_8
# creating new dense layer
# dense_9
# creating new dense layer
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# conv2d_9
# creating new conv layer
# max_pooling2d_6
# creating new max pool layer
# conv2d_10
# creating new conv layer
# max_pooling2d_7
# creating new max pool layer
# conv2d_11
# creating new conv layer
# max_pooling2d_8
# creating new max pool layer
# flatten_5
# creating new flatten layer
# dense_10
# creating new dense layer
# dense_11
# creating new dense layer

# %%
def scratch_predict(model):
    preds = network.predict(model,x_test)
    preds_classes = np.argmax(preds, axis=1)

    # Flatten label test karena aslinya (10000,1)
    y_test_flat = y_test.flatten()

    # Hitung Macro F1
    scratch_macro_f1 = f1_score(y_test_flat, preds_classes, average='macro')
    # print("Macro F1-Score on Test Set:", scratch_macro_f1)
    return scratch_macro_f1

# %%
# accuracy1 = scratch_predict(ScratchModel1)
# accuracy2 = scratch_predict(ScratchModel2)
# accuracy3 = scratch_predict(ScratchModel3)

# %%
# print("Macro F1-Score on Test Set:", accuracy1)
# print("Macro F1-Score on Test Set:", accuracy2)
# print("Macro F1-Score on Test Set:", accuracy3)
