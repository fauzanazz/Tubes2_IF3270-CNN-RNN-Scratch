# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# Normalisasi
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Split train jadi train + validation (4:1)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42
)

print("Train:", x_train.shape)
print("Validation:", x_val.shape)
print("Test:", x_test.shape)
# Out:
# Train: (40000, 32, 32, 3)
# Validation: (10000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(8, (3, 3), activation='relu'))
model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Flatten())
model1.add(layers.Dense(8, activation='relu'))
model1.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model1.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model2 = models.Sequential()
model2.add(layers.Conv2D(8, (9, 9), activation='relu'))
model2.add(layers.MaxPooling2D((2, 2)))
model2.add(layers.Flatten())
model2.add(layers.Dense(8, activation='relu'))
model2.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas

model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model3 = models.Sequential()
model3.add(layers.Conv2D(8, (27, 27), activation='relu'))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Flatten())
model3.add(layers.Dense(8, activation='relu'))
model3.add(layers.Dense(10, activation='softmax'))  # CIFAR-10 → 10 kelas
model3.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
def train_model(model):
    history = model.fit(
        x_train, y_train,
        epochs=20,
        validation_data=(x_val, y_val),
        batch_size=64,
        verbose = 1
    )
    return history

# %%
history1 = train_model(model1)
history2 = train_model(model2)
history3 = train_model(model3)
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.1595 - loss: 2.2312 - val_accuracy: 0.1790 - val_loss: 2.0742
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1862 - loss: 2.0566 - val_accuracy: 0.1945 - val_loss: 1.9884
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1932 - loss: 1.9797 - val_accuracy: 0.1932 - val_loss: 1.9861
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2040 - loss: 1.9404 - val_accuracy: 0.2071 - val_loss: 1.9130
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2059 - loss: 1.9175 - val_accuracy: 0.2035 - val_loss: 1.8966
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2028 - loss: 1.8937 - val_accuracy: 0.2067 - val_loss: 1.8845
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2089 - loss: 1.8781 - val_accuracy: 0.2080 - val_loss: 1.8772
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2089 - loss: 1.8837 - val_accuracy: 0.1989 - val_loss: 1.9142
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2110 - loss: 1.8793 - val_accuracy: 0.2091 - val_loss: 1.8749
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2110 - loss: 1.8632 - val_accuracy: 0.2059 - val_loss: 1.8618
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2126 - loss: 1.8572 - val_accuracy: 0.2076 - val_loss: 1.8731
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2111 - loss: 1.8567 - val_accuracy: 0.2053 - val_loss: 1.8569
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2103 - loss: 1.8534 - val_accuracy: 0.2006 - val_loss: 1.8525
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2152 - loss: 1.8529 - val_accuracy: 0.2049 - val_loss: 1.8633
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2172 - loss: 1.8460 - val_accuracy: 0.2104 - val_loss: 1.8470
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2157 - loss: 1.8491 - val_accuracy: 0.2052 - val_loss: 1.8487
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2156 - loss: 1.8458 - val_accuracy: 0.1968 - val_loss: 1.8500
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2107 - loss: 1.8433 - val_accuracy: 0.2121 - val_loss: 1.8410
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.2157 - loss: 1.8320 - val_accuracy: 0.2100 - val_loss: 1.8399
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2198 - loss: 1.8327 - val_accuracy: 0.2129 - val_loss: 1.8413
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.1745 - loss: 2.1727 - val_accuracy: 0.3010 - val_loss: 1.8801
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3109 - loss: 1.8454 - val_accuracy: 0.3420 - val_loss: 1.7469
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3542 - loss: 1.7188 - val_accuracy: 0.3735 - val_loss: 1.6630
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3709 - loss: 1.6644 - val_accuracy: 0.3681 - val_loss: 1.6806
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3861 - loss: 1.6339 - val_accuracy: 0.3787 - val_loss: 1.6532
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4057 - loss: 1.6037 - val_accuracy: 0.4112 - val_loss: 1.5906
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4116 - loss: 1.5782 - val_accuracy: 0.3990 - val_loss: 1.6185
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4327 - loss: 1.5353 - val_accuracy: 0.4300 - val_loss: 1.5412
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4412 - loss: 1.5159 - val_accuracy: 0.4223 - val_loss: 1.5783
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4500 - loss: 1.5013 - val_accuracy: 0.4110 - val_loss: 1.5893
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4564 - loss: 1.4924 - val_accuracy: 0.4437 - val_loss: 1.5044
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4600 - loss: 1.4705 - val_accuracy: 0.4570 - val_loss: 1.4877
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4645 - loss: 1.4550 - val_accuracy: 0.4596 - val_loss: 1.4749
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4677 - loss: 1.4431 - val_accuracy: 0.4605 - val_loss: 1.4737
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4723 - loss: 1.4255 - val_accuracy: 0.4442 - val_loss: 1.4922
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4779 - loss: 1.4273 - val_accuracy: 0.4753 - val_loss: 1.4520
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4849 - loss: 1.4032 - val_accuracy: 0.4675 - val_loss: 1.4534
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4864 - loss: 1.3995 - val_accuracy: 0.4755 - val_loss: 1.4442
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4931 - loss: 1.3837 - val_accuracy: 0.4587 - val_loss: 1.4922
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4952 - loss: 1.3771 - val_accuracy: 0.4803 - val_loss: 1.4372
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.1006 - loss: 2.3043 - val_accuracy: 0.0932 - val_loss: 2.3028
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.0990 - loss: 2.3028 - val_accuracy: 0.0932 - val_loss: 2.3031
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.0985 - loss: 2.3027 - val_accuracy: 0.0932 - val_loss: 2.3030
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1363 - loss: 2.2528 - val_accuracy: 0.2264 - val_loss: 2.0869
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2278 - loss: 2.0743 - val_accuracy: 0.2380 - val_loss: 2.0291
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2415 - loss: 2.0298 - val_accuracy: 0.2358 - val_loss: 2.0221
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2448 - loss: 2.0188 - val_accuracy: 0.2385 - val_loss: 2.0163
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2548 - loss: 2.0038 - val_accuracy: 0.2408 - val_loss: 2.0138
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2532 - loss: 2.0000 - val_accuracy: 0.2454 - val_loss: 2.0048
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2555 - loss: 2.0026 - val_accuracy: 0.2396 - val_loss: 2.0181
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2592 - loss: 1.9913 - val_accuracy: 0.2474 - val_loss: 1.9913
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2598 - loss: 1.9855 - val_accuracy: 0.2518 - val_loss: 2.0002
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2607 - loss: 1.9862 - val_accuracy: 0.2518 - val_loss: 1.9855
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2649 - loss: 1.9753 - val_accuracy: 0.2567 - val_loss: 1.9789
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2709 - loss: 1.9614 - val_accuracy: 0.2571 - val_loss: 1.9783
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2697 - loss: 1.9655 - val_accuracy: 0.2552 - val_loss: 1.9846
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2681 - loss: 1.9688 - val_accuracy: 0.2526 - val_loss: 1.9819
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2738 - loss: 1.9599 - val_accuracy: 0.2605 - val_loss: 1.9740
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2761 - loss: 1.9547 - val_accuracy: 0.2629 - val_loss: 1.9688
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2734 - loss: 1.9616 - val_accuracy: 0.2627 - val_loss: 1.9662

# %%
# Prediksi test set
def predict_with(model):

    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Flatten label test karena aslinya (10000,1)
    y_test_flat = y_test.flatten()

    # Hitung Macro F1
    macro_f1 = f1_score(y_test_flat, y_pred_classes, average='macro')
    print("Macro F1-Score on Test Set:", macro_f1)

# %%
predict_with(model1)
predict_with(model2)
predict_with(model3)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Macro F1-Score on Test Set: 0.14648750545247657
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Macro F1-Score on Test Set: 0.47086888925546366
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Macro F1-Score on Test Set: 0.23728632309578906

# %%
import matplotlib.pyplot as plt

def plot_loss_histories(histories, labels):
    """Membuat grafik training dan validation loss dari beberapa riwayat pelatihan.

    Args:
        histories (list): Daftar objek History (hasil dari model.fit).
        labels (list): Daftar label yang sesuai untuk setiap riwayat.

    Returns:
        None (menampilkan grafik)
    """

    # Grafik Training Loss
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, grafik pertama
    for history, label in zip(histories, labels):
        plt.plot(history.history['loss'], label=label)
    plt.title('Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Grafik Validation Loss
    plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, grafik kedua
    for history, label in zip(histories, labels):
        plt.plot(history.history['val_loss'], label=label)
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()  # Menyesuaikan tata letak agar tidak tumpang tindih
    plt.show()

# %%
plot_loss_histories([history1,history2,history3],['Model1','Model2','Model3'])

# %%
model1.save('../models/test2_model_1.h5')
model2.save('../models/test2_model_2.h5')
model3.save('../models/test2_model_3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import sys
import os

dir_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if dir_path not in sys.path:
    sys.path.insert(0, dir_path)

try:
    from implementation import load
    from implementation import network
    print("Successfully imported 'load' and 'network' from the 'modules' package.")

except ImportError as e:
    print(f"Error importing modules: {e}")
# Out:
# Successfully imported 'load' and 'network' from the 'modules' package.

# %%
ScratchModel1 =load.load_scratch_model('../models/test2_model_1.h5')
ScratchModel2 =load.load_scratch_model('../models/test2_model_2.h5')
ScratchModel3 =load.load_scratch_model('../models/test2_model_3.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# conv2d
# creating new conv layer
# max_pooling2d
# creating new max pool layer
# flatten
# creating new flatten layer
# dense
# creating new dense layer
# dense_1
# creating new dense layer
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# conv2d_1
# creating new conv layer
# max_pooling2d_1
# creating new max pool layer
# flatten_1
# creating new flatten layer
# dense_2
# creating new dense layer
# dense_3
# creating new dense layer
# conv2d_2
# creating new conv layer
# max_pooling2d_2
# creating new max pool layer
# flatten_2
# creating new flatten layer
# dense_4
# creating new dense layer
# dense_5
# creating new dense layer

# %%
def scratch_predict(model):
    preds = network.predict(model,x_test)
    preds_classes = np.argmax(preds, axis=1)

    # Flatten label test karena aslinya (10000,1)
    y_test_flat = y_test.flatten()

    # Hitung Macro F1
    scratch_macro_f1 = f1_score(y_test_flat, preds_classes, average='macro')
    # print("Macro F1-Score on Test Set:", scratch_macro_f1)
    return scratch_macro_f1

# %%
accuracy1 = scratch_predict(ScratchModel1)
accuracy2 = scratch_predict(ScratchModel2)
accuracy3 = scratch_predict(ScratchModel3)
# Out:
# mulai prediksi batch ke- 0 dari 312
# mulai prediksi batch ke- 1 dari 312
# mulai prediksi batch ke- 2 dari 312
# mulai prediksi batch ke- 3 dari 312
# mulai prediksi batch ke- 4 dari 312
# mulai prediksi batch ke- 5 dari 312
# mulai prediksi batch ke- 6 dari 312
# mulai prediksi batch ke- 7 dari 312
# mulai prediksi batch ke- 8 dari 312
# mulai prediksi batch ke- 9 dari 312
# mulai prediksi batch ke- 10 dari 312
# mulai prediksi batch ke- 11 dari 312
# mulai prediksi batch ke- 12 dari 312
# mulai prediksi batch ke- 13 dari 312
# mulai prediksi batch ke- 14 dari 312
# mulai prediksi batch ke- 15 dari 312
# mulai prediksi batch ke- 16 dari 312
# mulai prediksi batch ke- 17 dari 312
# mulai prediksi batch ke- 18 dari 312
# mulai prediksi batch ke- 19 dari 312
# mulai prediksi batch ke- 20 dari 312
# mulai prediksi batch ke- 21 dari 312
# mulai prediksi batch ke- 22 dari 312
# mulai prediksi batch ke- 23 dari 312
# mulai prediksi batch ke- 24 dari 312
# mulai prediksi batch ke- 25 dari 312
# mulai prediksi batch ke- 26 dari 312
# mulai prediksi batch ke- 27 dari 312
# mulai prediksi batch ke- 28 dari 312
# mulai prediksi batch ke- 29 dari 312
# mulai prediksi batch ke- 30 dari 312
# mulai prediksi batch ke- 31 dari 312
# mulai prediksi batch ke- 32 dari 312
# mulai prediksi batch ke- 33 dari 312
# mulai prediksi batch ke- 34 dari 312
# mulai prediksi batch ke- 35 dari 312
# mulai prediksi batch ke- 36 dari 312
# mulai prediksi batch ke- 37 dari 312
# mulai prediksi batch ke- 38 dari 312
# mulai prediksi batch ke- 39 dari 312
# mulai prediksi batch ke- 40 dari 312
# mulai prediksi batch ke- 41 dari 312
# mulai prediksi batch ke- 42 dari 312
# mulai prediksi batch ke- 43 dari 312
# mulai prediksi batch ke- 44 dari 312
# mulai prediksi batch ke- 45 dari 312
# mulai prediksi batch ke- 46 dari 312
# mulai prediksi batch ke- 47 dari 312
# mulai prediksi batch ke- 48 dari 312
# mulai prediksi batch ke- 49 dari 312
# mulai prediksi batch ke- 50 dari 312
# mulai prediksi batch ke- 51 dari 312
# mulai prediksi batch ke- 52 dari 312
# mulai prediksi batch ke- 53 dari 312
# mulai prediksi batch ke- 54 dari 312
# mulai prediksi batch ke- 55 dari 312
# mulai prediksi batch ke- 56 dari 312
# mulai prediksi batch ke- 57 dari 312
# mulai prediksi batch ke- 58 dari 312
# mulai prediksi batch ke- 59 dari 312
# mulai prediksi batch ke- 60 dari 312
# mulai prediksi batch ke- 61 dari 312
# mulai prediksi batch ke- 62 dari 312
# mulai prediksi batch ke- 63 dari 312
# mulai prediksi batch ke- 64 dari 312
# mulai prediksi batch ke- 65 dari 312
# mulai prediksi batch ke- 66 dari 312
# mulai prediksi batch ke- 67 dari 312
# mulai prediksi batch ke- 68 dari 312
# mulai prediksi batch ke- 69 dari 312
# mulai prediksi batch ke- 70 dari 312
# mulai prediksi batch ke- 71 dari 312
# mulai prediksi batch ke- 72 dari 312
# mulai prediksi batch ke- 73 dari 312
# mulai prediksi batch ke- 74 dari 312
# mulai prediksi batch ke- 75 dari 312
# mulai prediksi batch ke- 76 dari 312
# mulai prediksi batch ke- 77 dari 312
# mulai prediksi batch ke- 78 dari 312
# mulai prediksi batch ke- 79 dari 312
# mulai prediksi batch ke- 80 dari 312
# mulai prediksi batch ke- 81 dari 312
# mulai prediksi batch ke- 82 dari 312
# mulai prediksi batch ke- 83 dari 312
# mulai prediksi batch ke- 84 dari 312
# mulai prediksi batch ke- 85 dari 312
# mulai prediksi batch ke- 86 dari 312
# mulai prediksi batch ke- 87 dari 312
# mulai prediksi batch ke- 88 dari 312
# mulai prediksi batch ke- 89 dari 312
# mulai prediksi batch ke- 90 dari 312
# mulai prediksi batch ke- 91 dari 312
# mulai prediksi batch ke- 92 dari 312
# mulai prediksi batch ke- 93 dari 312
# mulai prediksi batch ke- 94 dari 312
# mulai prediksi batch ke- 95 dari 312
# mulai prediksi batch ke- 96 dari 312
# mulai prediksi batch ke- 97 dari 312
# mulai prediksi batch ke- 98 dari 312
# mulai prediksi batch ke- 99 dari 312
# mulai prediksi batch ke- 100 dari 312
# mulai prediksi batch ke- 101 dari 312
# mulai prediksi batch ke- 102 dari 312
# mulai prediksi batch ke- 103 dari 312
# mulai prediksi batch ke- 104 dari 312
# mulai prediksi batch ke- 105 dari 312
# mulai prediksi batch ke- 106 dari 312
# mulai prediksi batch ke- 107 dari 312
# mulai prediksi batch ke- 108 dari 312
# mulai prediksi batch ke- 109 dari 312
# mulai prediksi batch ke- 110 dari 312
# mulai prediksi batch ke- 111 dari 312
# mulai prediksi batch ke- 112 dari 312
# mulai prediksi batch ke- 113 dari 312
# mulai prediksi batch ke- 114 dari 312
# mulai prediksi batch ke- 115 dari 312
# mulai prediksi batch ke- 116 dari 312
# mulai prediksi batch ke- 117 dari 312
# mulai prediksi batch ke- 118 dari 312
# mulai prediksi batch ke- 119 dari 312
# mulai prediksi batch ke- 120 dari 312
# mulai prediksi batch ke- 121 dari 312
# mulai prediksi batch ke- 122 dari 312
# mulai prediksi batch ke- 123 dari 312
# mulai prediksi batch ke- 124 dari 312
# mulai prediksi batch ke- 125 dari 312
# mulai prediksi batch ke- 126 dari 312
# mulai prediksi batch ke- 127 dari 312
# mulai prediksi batch ke- 128 dari 312
# mulai prediksi batch ke- 129 dari 312
# mulai prediksi batch ke- 130 dari 312
# mulai prediksi batch ke- 131 dari 312
# mulai prediksi batch ke- 132 dari 312
# mulai prediksi batch ke- 133 dari 312
# mulai prediksi batch ke- 134 dari 312
# mulai prediksi batch ke- 135 dari 312
# mulai prediksi batch ke- 136 dari 312
# mulai prediksi batch ke- 137 dari 312
# mulai prediksi batch ke- 138 dari 312
# mulai prediksi batch ke- 139 dari 312
# mulai prediksi batch ke- 140 dari 312
# mulai prediksi batch ke- 141 dari 312
# mulai prediksi batch ke- 142 dari 312
# mulai prediksi batch ke- 143 dari 312
# mulai prediksi batch ke- 144 dari 312
# mulai prediksi batch ke- 145 dari 312
# mulai prediksi batch ke- 146 dari 312
# mulai prediksi batch ke- 147 dari 312
# mulai prediksi batch ke- 148 dari 312
# mulai prediksi batch ke- 149 dari 312
# mulai prediksi batch ke- 150 dari 312
# mulai prediksi batch ke- 151 dari 312
# mulai prediksi batch ke- 152 dari 312
# mulai prediksi batch ke- 153 dari 312
# mulai prediksi batch ke- 154 dari 312
# mulai prediksi batch ke- 155 dari 312
# mulai prediksi batch ke- 156 dari 312
# mulai prediksi batch ke- 157 dari 312
# mulai prediksi batch ke- 158 dari 312
# mulai prediksi batch ke- 159 dari 312
# mulai prediksi batch ke- 160 dari 312
# mulai prediksi batch ke- 161 dari 312
# mulai prediksi batch ke- 162 dari 312
# mulai prediksi batch ke- 163 dari 312
# mulai prediksi batch ke- 164 dari 312
# mulai prediksi batch ke- 165 dari 312
# mulai prediksi batch ke- 166 dari 312
# mulai prediksi batch ke- 167 dari 312
# mulai prediksi batch ke- 168 dari 312
# mulai prediksi batch ke- 169 dari 312
# mulai prediksi batch ke- 170 dari 312
# mulai prediksi batch ke- 171 dari 312
# mulai prediksi batch ke- 172 dari 312
# mulai prediksi batch ke- 173 dari 312
# mulai prediksi batch ke- 174 dari 312
# mulai prediksi batch ke- 175 dari 312
# mulai prediksi batch ke- 176 dari 312
# mulai prediksi batch ke- 177 dari 312
# mulai prediksi batch ke- 178 dari 312
# mulai prediksi batch ke- 179 dari 312
# mulai prediksi batch ke- 180 dari 312
# mulai prediksi batch ke- 181 dari 312
# mulai prediksi batch ke- 182 dari 312
# mulai prediksi batch ke- 183 dari 312
# mulai prediksi batch ke- 184 dari 312
# mulai prediksi batch ke- 185 dari 312
# mulai prediksi batch ke- 186 dari 312
# mulai prediksi batch ke- 187 dari 312
# mulai prediksi batch ke- 188 dari 312
# mulai prediksi batch ke- 189 dari 312
# mulai prediksi batch ke- 190 dari 312
# mulai prediksi batch ke- 191 dari 312
# mulai prediksi batch ke- 192 dari 312
# mulai prediksi batch ke- 193 dari 312
# mulai prediksi batch ke- 194 dari 312
# mulai prediksi batch ke- 195 dari 312
# mulai prediksi batch ke- 196 dari 312
# mulai prediksi batch ke- 197 dari 312
# mulai prediksi batch ke- 198 dari 312
# mulai prediksi batch ke- 199 dari 312
# mulai prediksi batch ke- 200 dari 312
# mulai prediksi batch ke- 201 dari 312
# mulai prediksi batch ke- 202 dari 312
# mulai prediksi batch ke- 203 dari 312
# mulai prediksi batch ke- 204 dari 312
# mulai prediksi batch ke- 205 dari 312
# mulai prediksi batch ke- 206 dari 312
# mulai prediksi batch ke- 207 dari 312
# mulai prediksi batch ke- 208 dari 312
# mulai prediksi batch ke- 209 dari 312
# mulai prediksi batch ke- 210 dari 312
# mulai prediksi batch ke- 211 dari 312
# mulai prediksi batch ke- 212 dari 312
# mulai prediksi batch ke- 213 dari 312
# mulai prediksi batch ke- 214 dari 312
# mulai prediksi batch ke- 215 dari 312
# mulai prediksi batch ke- 216 dari 312
# mulai prediksi batch ke- 217 dari 312
# mulai prediksi batch ke- 218 dari 312
# mulai prediksi batch ke- 219 dari 312
# mulai prediksi batch ke- 220 dari 312
# mulai prediksi batch ke- 221 dari 312
# mulai prediksi batch ke- 222 dari 312
# mulai prediksi batch ke- 223 dari 312
# mulai prediksi batch ke- 224 dari 312
# mulai prediksi batch ke- 225 dari 312
# mulai prediksi batch ke- 226 dari 312
# mulai prediksi batch ke- 227 dari 312
# mulai prediksi batch ke- 228 dari 312
# mulai prediksi batch ke- 229 dari 312
# mulai prediksi batch ke- 230 dari 312
# mulai prediksi batch ke- 231 dari 312
# mulai prediksi batch ke- 232 dari 312
# mulai prediksi batch ke- 233 dari 312
# mulai prediksi batch ke- 234 dari 312
# mulai prediksi batch ke- 235 dari 312
# mulai prediksi batch ke- 236 dari 312
# mulai prediksi batch ke- 237 dari 312
# mulai prediksi batch ke- 238 dari 312
# mulai prediksi batch ke- 239 dari 312
# mulai prediksi batch ke- 240 dari 312
# mulai prediksi batch ke- 241 dari 312
# mulai prediksi batch ke- 242 dari 312
# mulai prediksi batch ke- 243 dari 312
# mulai prediksi batch ke- 244 dari 312
# mulai prediksi batch ke- 245 dari 312
# mulai prediksi batch ke- 246 dari 312
# mulai prediksi batch ke- 247 dari 312
# mulai prediksi batch ke- 248 dari 312
# mulai prediksi batch ke- 249 dari 312
# mulai prediksi batch ke- 250 dari 312
# mulai prediksi batch ke- 251 dari 312
# mulai prediksi batch ke- 252 dari 312
# mulai prediksi batch ke- 253 dari 312
# mulai prediksi batch ke- 254 dari 312
# mulai prediksi batch ke- 255 dari 312
# mulai prediksi batch ke- 256 dari 312
# mulai prediksi batch ke- 257 dari 312
# mulai prediksi batch ke- 258 dari 312
# mulai prediksi batch ke- 259 dari 312
# mulai prediksi batch ke- 260 dari 312
# mulai prediksi batch ke- 261 dari 312
# mulai prediksi batch ke- 262 dari 312
# mulai prediksi batch ke- 263 dari 312
# mulai prediksi batch ke- 264 dari 312
# mulai prediksi batch ke- 265 dari 312
# mulai prediksi batch ke- 266 dari 312
# mulai prediksi batch ke- 267 dari 312
# mulai prediksi batch ke- 268 dari 312
# mulai prediksi batch ke- 269 dari 312
# mulai prediksi batch ke- 270 dari 312
# mulai prediksi batch ke- 271 dari 312
# mulai prediksi batch ke- 272 dari 312
# mulai prediksi batch ke- 273 dari 312
# mulai prediksi batch ke- 274 dari 312
# mulai prediksi batch ke- 275 dari 312
# mulai prediksi batch ke- 276 dari 312
# mulai prediksi batch ke- 277 dari 312
# mulai prediksi batch ke- 278 dari 312
# mulai prediksi batch ke- 279 dari 312
# mulai prediksi batch ke- 280 dari 312
# mulai prediksi batch ke- 281 dari 312
# mulai prediksi batch ke- 282 dari 312
# mulai prediksi batch ke- 283 dari 312
# mulai prediksi batch ke- 284 dari 312
# mulai prediksi batch ke- 285 dari 312
# mulai prediksi batch ke- 286 dari 312
# mulai prediksi batch ke- 287 dari 312
# mulai prediksi batch ke- 288 dari 312
# mulai prediksi batch ke- 289 dari 312
# mulai prediksi batch ke- 290 dari 312
# mulai prediksi batch ke- 291 dari 312
# mulai prediksi batch ke- 292 dari 312
# mulai prediksi batch ke- 293 dari 312
# mulai prediksi batch ke- 294 dari 312
# mulai prediksi batch ke- 295 dari 312
# mulai prediksi batch ke- 296 dari 312
# mulai prediksi batch ke- 297 dari 312
# mulai prediksi batch ke- 298 dari 312
# mulai prediksi batch ke- 299 dari 312
# mulai prediksi batch ke- 300 dari 312
# mulai prediksi batch ke- 301 dari 312
# mulai prediksi batch ke- 302 dari 312
# mulai prediksi batch ke- 303 dari 312
# mulai prediksi batch ke- 304 dari 312
# mulai prediksi batch ke- 305 dari 312
# mulai prediksi batch ke- 306 dari 312
# mulai prediksi batch ke- 307 dari 312
# mulai prediksi batch ke- 308 dari 312
# mulai prediksi batch ke- 309 dari 312
# mulai prediksi batch ke- 310 dari 312
# mulai prediksi batch ke- 311 dari 312
# mulai prediksi batch ke- 312 dari 312
# mulai prediksi batch ke- 0 dari 312
# mulai prediksi batch ke- 1 dari 312
# mulai prediksi batch ke- 2 dari 312
# mulai prediksi batch ke- 3 dari 312
# mulai prediksi batch ke- 4 dari 312
# mulai prediksi batch ke- 5 dari 312
# mulai prediksi batch ke- 6 dari 312
# mulai prediksi batch ke- 7 dari 312
# mulai prediksi batch ke- 8 dari 312
# mulai prediksi batch ke- 9 dari 312
# mulai prediksi batch ke- 10 dari 312
# mulai prediksi batch ke- 11 dari 312
# mulai prediksi batch ke- 12 dari 312
# mulai prediksi batch ke- 13 dari 312
# mulai prediksi batch ke- 14 dari 312
# mulai prediksi batch ke- 15 dari 312
# mulai prediksi batch ke- 16 dari 312
# mulai prediksi batch ke- 17 dari 312
# mulai prediksi batch ke- 18 dari 312
# mulai prediksi batch ke- 19 dari 312
# mulai prediksi batch ke- 20 dari 312
# mulai prediksi batch ke- 21 dari 312
# mulai prediksi batch ke- 22 dari 312
# mulai prediksi batch ke- 23 dari 312
# mulai prediksi batch ke- 24 dari 312
# mulai prediksi batch ke- 25 dari 312
# mulai prediksi batch ke- 26 dari 312
# mulai prediksi batch ke- 27 dari 312
# mulai prediksi batch ke- 28 dari 312
# mulai prediksi batch ke- 29 dari 312
# mulai prediksi batch ke- 30 dari 312
# mulai prediksi batch ke- 31 dari 312
# mulai prediksi batch ke- 32 dari 312
# mulai prediksi batch ke- 33 dari 312
# mulai prediksi batch ke- 34 dari 312
# mulai prediksi batch ke- 35 dari 312
# mulai prediksi batch ke- 36 dari 312
# mulai prediksi batch ke- 37 dari 312
# mulai prediksi batch ke- 38 dari 312
# mulai prediksi batch ke- 39 dari 312
# mulai prediksi batch ke- 40 dari 312
# mulai prediksi batch ke- 41 dari 312
# mulai prediksi batch ke- 42 dari 312
# mulai prediksi batch ke- 43 dari 312
# mulai prediksi batch ke- 44 dari 312
# mulai prediksi batch ke- 45 dari 312
# mulai prediksi batch ke- 46 dari 312
# mulai prediksi batch ke- 47 dari 312
# mulai prediksi batch ke- 48 dari 312
# mulai prediksi batch ke- 49 dari 312
# mulai prediksi batch ke- 50 dari 312
# mulai prediksi batch ke- 51 dari 312
# mulai prediksi batch ke- 52 dari 312
# mulai prediksi batch ke- 53 dari 312
# mulai prediksi batch ke- 54 dari 312
# mulai prediksi batch ke- 55 dari 312
# mulai prediksi batch ke- 56 dari 312
# mulai prediksi batch ke- 57 dari 312
# mulai prediksi batch ke- 58 dari 312
# mulai prediksi batch ke- 59 dari 312
# mulai prediksi batch ke- 60 dari 312
# mulai prediksi batch ke- 61 dari 312
# mulai prediksi batch ke- 62 dari 312
# mulai prediksi batch ke- 63 dari 312
# mulai prediksi batch ke- 64 dari 312
# mulai prediksi batch ke- 65 dari 312
# mulai prediksi batch ke- 66 dari 312
# mulai prediksi batch ke- 67 dari 312
# mulai prediksi batch ke- 68 dari 312
# mulai prediksi batch ke- 69 dari 312
# mulai prediksi batch ke- 70 dari 312
# mulai prediksi batch ke- 71 dari 312
# mulai prediksi batch ke- 72 dari 312
# mulai prediksi batch ke- 73 dari 312
# mulai prediksi batch ke- 74 dari 312
# mulai prediksi batch ke- 75 dari 312
# mulai prediksi batch ke- 76 dari 312
# mulai prediksi batch ke- 77 dari 312
# mulai prediksi batch ke- 78 dari 312
# mulai prediksi batch ke- 79 dari 312
# mulai prediksi batch ke- 80 dari 312
# mulai prediksi batch ke- 81 dari 312
# mulai prediksi batch ke- 82 dari 312
# mulai prediksi batch ke- 83 dari 312
# mulai prediksi batch ke- 84 dari 312
# mulai prediksi batch ke- 85 dari 312
# mulai prediksi batch ke- 86 dari 312
# mulai prediksi batch ke- 87 dari 312
# mulai prediksi batch ke- 88 dari 312
# mulai prediksi batch ke- 89 dari 312
# mulai prediksi batch ke- 90 dari 312
# mulai prediksi batch ke- 91 dari 312
# mulai prediksi batch ke- 92 dari 312
# mulai prediksi batch ke- 93 dari 312
# mulai prediksi batch ke- 94 dari 312
# mulai prediksi batch ke- 95 dari 312
# mulai prediksi batch ke- 96 dari 312
# mulai prediksi batch ke- 97 dari 312
# mulai prediksi batch ke- 98 dari 312
# mulai prediksi batch ke- 99 dari 312
# mulai prediksi batch ke- 100 dari 312
# mulai prediksi batch ke- 101 dari 312
# mulai prediksi batch ke- 102 dari 312
# mulai prediksi batch ke- 103 dari 312
# mulai prediksi batch ke- 104 dari 312
# mulai prediksi batch ke- 105 dari 312
# mulai prediksi batch ke- 106 dari 312
# mulai prediksi batch ke- 107 dari 312
# mulai prediksi batch ke- 108 dari 312
# mulai prediksi batch ke- 109 dari 312
# mulai prediksi batch ke- 110 dari 312
# mulai prediksi batch ke- 111 dari 312
# mulai prediksi batch ke- 112 dari 312
# mulai prediksi batch ke- 113 dari 312
# mulai prediksi batch ke- 114 dari 312
# mulai prediksi batch ke- 115 dari 312
# mulai prediksi batch ke- 116 dari 312
# mulai prediksi batch ke- 117 dari 312
# mulai prediksi batch ke- 118 dari 312
# mulai prediksi batch ke- 119 dari 312
# mulai prediksi batch ke- 120 dari 312
# mulai prediksi batch ke- 121 dari 312
# mulai prediksi batch ke- 122 dari 312
# mulai prediksi batch ke- 123 dari 312
# mulai prediksi batch ke- 124 dari 312
# mulai prediksi batch ke- 125 dari 312
# mulai prediksi batch ke- 126 dari 312
# mulai prediksi batch ke- 127 dari 312
# mulai prediksi batch ke- 128 dari 312
# mulai prediksi batch ke- 129 dari 312
# mulai prediksi batch ke- 130 dari 312
# mulai prediksi batch ke- 131 dari 312
# mulai prediksi batch ke- 132 dari 312
# mulai prediksi batch ke- 133 dari 312
# mulai prediksi batch ke- 134 dari 312
# mulai prediksi batch ke- 135 dari 312
# mulai prediksi batch ke- 136 dari 312
# mulai prediksi batch ke- 137 dari 312
# mulai prediksi batch ke- 138 dari 312
# mulai prediksi batch ke- 139 dari 312
# mulai prediksi batch ke- 140 dari 312
# mulai prediksi batch ke- 141 dari 312
# mulai prediksi batch ke- 142 dari 312
# mulai prediksi batch ke- 143 dari 312
# mulai prediksi batch ke- 144 dari 312
# mulai prediksi batch ke- 145 dari 312
# mulai prediksi batch ke- 146 dari 312
# mulai prediksi batch ke- 147 dari 312
# mulai prediksi batch ke- 148 dari 312
# mulai prediksi batch ke- 149 dari 312
# mulai prediksi batch ke- 150 dari 312
# mulai prediksi batch ke- 151 dari 312
# mulai prediksi batch ke- 152 dari 312
# mulai prediksi batch ke- 153 dari 312
# mulai prediksi batch ke- 154 dari 312
# mulai prediksi batch ke- 155 dari 312
# mulai prediksi batch ke- 156 dari 312
# mulai prediksi batch ke- 157 dari 312
# mulai prediksi batch ke- 158 dari 312
# mulai prediksi batch ke- 159 dari 312
# mulai prediksi batch ke- 160 dari 312
# mulai prediksi batch ke- 161 dari 312
# mulai prediksi batch ke- 162 dari 312
# mulai prediksi batch ke- 163 dari 312
# mulai prediksi batch ke- 164 dari 312
# mulai prediksi batch ke- 165 dari 312
# mulai prediksi batch ke- 166 dari 312
# mulai prediksi batch ke- 167 dari 312
# mulai prediksi batch ke- 168 dari 312
# mulai prediksi batch ke- 169 dari 312
# mulai prediksi batch ke- 170 dari 312
# mulai prediksi batch ke- 171 dari 312
# mulai prediksi batch ke- 172 dari 312
# mulai prediksi batch ke- 173 dari 312
# mulai prediksi batch ke- 174 dari 312
# mulai prediksi batch ke- 175 dari 312
# mulai prediksi batch ke- 176 dari 312
# mulai prediksi batch ke- 177 dari 312
# mulai prediksi batch ke- 178 dari 312
# mulai prediksi batch ke- 179 dari 312
# mulai prediksi batch ke- 180 dari 312
# mulai prediksi batch ke- 181 dari 312
# mulai prediksi batch ke- 182 dari 312
# mulai prediksi batch ke- 183 dari 312
# mulai prediksi batch ke- 184 dari 312
# mulai prediksi batch ke- 185 dari 312
# mulai prediksi batch ke- 186 dari 312
# mulai prediksi batch ke- 187 dari 312
# mulai prediksi batch ke- 188 dari 312
# mulai prediksi batch ke- 189 dari 312
# mulai prediksi batch ke- 190 dari 312
# mulai prediksi batch ke- 191 dari 312
# mulai prediksi batch ke- 192 dari 312
# mulai prediksi batch ke- 193 dari 312
# mulai prediksi batch ke- 194 dari 312
# mulai prediksi batch ke- 195 dari 312
# mulai prediksi batch ke- 196 dari 312
# mulai prediksi batch ke- 197 dari 312
# mulai prediksi batch ke- 198 dari 312
# mulai prediksi batch ke- 199 dari 312
# mulai prediksi batch ke- 200 dari 312
# mulai prediksi batch ke- 201 dari 312
# mulai prediksi batch ke- 202 dari 312
# mulai prediksi batch ke- 203 dari 312
# mulai prediksi batch ke- 204 dari 312
# mulai prediksi batch ke- 205 dari 312
# mulai prediksi batch ke- 206 dari 312
# mulai prediksi batch ke- 207 dari 312
# mulai prediksi batch ke- 208 dari 312
# mulai prediksi batch ke- 209 dari 312
# mulai prediksi batch ke- 210 dari 312
# mulai prediksi batch ke- 211 dari 312
# mulai prediksi batch ke- 212 dari 312
# mulai prediksi batch ke- 213 dari 312
# mulai prediksi batch ke- 214 dari 312
# mulai prediksi batch ke- 215 dari 312
# mulai prediksi batch ke- 216 dari 312
# mulai prediksi batch ke- 217 dari 312
# mulai prediksi batch ke- 218 dari 312
# mulai prediksi batch ke- 219 dari 312
# mulai prediksi batch ke- 220 dari 312
# mulai prediksi batch ke- 221 dari 312
# mulai prediksi batch ke- 222 dari 312
# mulai prediksi batch ke- 223 dari 312
# mulai prediksi batch ke- 224 dari 312
# mulai prediksi batch ke- 225 dari 312
# mulai prediksi batch ke- 226 dari 312
# mulai prediksi batch ke- 227 dari 312
# mulai prediksi batch ke- 228 dari 312
# mulai prediksi batch ke- 229 dari 312
# mulai prediksi batch ke- 230 dari 312
# mulai prediksi batch ke- 231 dari 312
# mulai prediksi batch ke- 232 dari 312
# mulai prediksi batch ke- 233 dari 312
# mulai prediksi batch ke- 234 dari 312
# mulai prediksi batch ke- 235 dari 312
# mulai prediksi batch ke- 236 dari 312
# mulai prediksi batch ke- 237 dari 312
# mulai prediksi batch ke- 238 dari 312
# mulai prediksi batch ke- 239 dari 312
# mulai prediksi batch ke- 240 dari 312
# mulai prediksi batch ke- 241 dari 312
# mulai prediksi batch ke- 242 dari 312
# mulai prediksi batch ke- 243 dari 312
# mulai prediksi batch ke- 244 dari 312
# mulai prediksi batch ke- 245 dari 312
# mulai prediksi batch ke- 246 dari 312
# mulai prediksi batch ke- 247 dari 312
# mulai prediksi batch ke- 248 dari 312
# mulai prediksi batch ke- 249 dari 312
# mulai prediksi batch ke- 250 dari 312
# mulai prediksi batch ke- 251 dari 312
# mulai prediksi batch ke- 252 dari 312
# mulai prediksi batch ke- 253 dari 312
# mulai prediksi batch ke- 254 dari 312
# mulai prediksi batch ke- 255 dari 312
# mulai prediksi batch ke- 256 dari 312
# mulai prediksi batch ke- 257 dari 312
# mulai prediksi batch ke- 258 dari 312
# mulai prediksi batch ke- 259 dari 312
# mulai prediksi batch ke- 260 dari 312
# mulai prediksi batch ke- 261 dari 312
# mulai prediksi batch ke- 262 dari 312
# mulai prediksi batch ke- 263 dari 312
# mulai prediksi batch ke- 264 dari 312
# mulai prediksi batch ke- 265 dari 312
# mulai prediksi batch ke- 266 dari 312
# mulai prediksi batch ke- 267 dari 312
# mulai prediksi batch ke- 268 dari 312
# mulai prediksi batch ke- 269 dari 312
# mulai prediksi batch ke- 270 dari 312
# mulai prediksi batch ke- 271 dari 312
# mulai prediksi batch ke- 272 dari 312
# mulai prediksi batch ke- 273 dari 312
# mulai prediksi batch ke- 274 dari 312
# mulai prediksi batch ke- 275 dari 312
# mulai prediksi batch ke- 276 dari 312
# mulai prediksi batch ke- 277 dari 312
# mulai prediksi batch ke- 278 dari 312
# mulai prediksi batch ke- 279 dari 312
# mulai prediksi batch ke- 280 dari 312
# mulai prediksi batch ke- 281 dari 312
# mulai prediksi batch ke- 282 dari 312
# mulai prediksi batch ke- 283 dari 312
# mulai prediksi batch ke- 284 dari 312
# mulai prediksi batch ke- 285 dari 312
# mulai prediksi batch ke- 286 dari 312
# mulai prediksi batch ke- 287 dari 312
# mulai prediksi batch ke- 288 dari 312
# mulai prediksi batch ke- 289 dari 312
# mulai prediksi batch ke- 290 dari 312
# mulai prediksi batch ke- 291 dari 312
# mulai prediksi batch ke- 292 dari 312
# mulai prediksi batch ke- 293 dari 312
# mulai prediksi batch ke- 294 dari 312
# mulai prediksi batch ke- 295 dari 312
# mulai prediksi batch ke- 296 dari 312
# mulai prediksi batch ke- 297 dari 312
# mulai prediksi batch ke- 298 dari 312
# mulai prediksi batch ke- 299 dari 312
# mulai prediksi batch ke- 300 dari 312
# mulai prediksi batch ke- 301 dari 312
# mulai prediksi batch ke- 302 dari 312
# mulai prediksi batch ke- 303 dari 312
# mulai prediksi batch ke- 304 dari 312
# mulai prediksi batch ke- 305 dari 312
# mulai prediksi batch ke- 306 dari 312
# mulai prediksi batch ke- 307 dari 312
# mulai prediksi batch ke- 308 dari 312
# mulai prediksi batch ke- 309 dari 312
# mulai prediksi batch ke- 310 dari 312
# mulai prediksi batch ke- 311 dari 312
# mulai prediksi batch ke- 312 dari 312
# mulai prediksi batch ke- 0 dari 312
# mulai prediksi batch ke- 1 dari 312
# mulai prediksi batch ke- 2 dari 312
# mulai prediksi batch ke- 3 dari 312
# mulai prediksi batch ke- 4 dari 312
# mulai prediksi batch ke- 5 dari 312
# mulai prediksi batch ke- 6 dari 312
# mulai prediksi batch ke- 7 dari 312
# mulai prediksi batch ke- 8 dari 312
# mulai prediksi batch ke- 9 dari 312
# mulai prediksi batch ke- 10 dari 312
# mulai prediksi batch ke- 11 dari 312
# mulai prediksi batch ke- 12 dari 312
# mulai prediksi batch ke- 13 dari 312
# mulai prediksi batch ke- 14 dari 312
# mulai prediksi batch ke- 15 dari 312
# mulai prediksi batch ke- 16 dari 312
# mulai prediksi batch ke- 17 dari 312
# mulai prediksi batch ke- 18 dari 312
# mulai prediksi batch ke- 19 dari 312
# mulai prediksi batch ke- 20 dari 312
# mulai prediksi batch ke- 21 dari 312
# mulai prediksi batch ke- 22 dari 312
# mulai prediksi batch ke- 23 dari 312
# mulai prediksi batch ke- 24 dari 312
# mulai prediksi batch ke- 25 dari 312
# mulai prediksi batch ke- 26 dari 312
# mulai prediksi batch ke- 27 dari 312
# mulai prediksi batch ke- 28 dari 312
# mulai prediksi batch ke- 29 dari 312
# mulai prediksi batch ke- 30 dari 312
# mulai prediksi batch ke- 31 dari 312
# mulai prediksi batch ke- 32 dari 312
# mulai prediksi batch ke- 33 dari 312
# mulai prediksi batch ke- 34 dari 312
# mulai prediksi batch ke- 35 dari 312
# mulai prediksi batch ke- 36 dari 312
# mulai prediksi batch ke- 37 dari 312
# mulai prediksi batch ke- 38 dari 312
# mulai prediksi batch ke- 39 dari 312
# mulai prediksi batch ke- 40 dari 312
# mulai prediksi batch ke- 41 dari 312
# mulai prediksi batch ke- 42 dari 312
# mulai prediksi batch ke- 43 dari 312
# mulai prediksi batch ke- 44 dari 312
# mulai prediksi batch ke- 45 dari 312
# mulai prediksi batch ke- 46 dari 312
# mulai prediksi batch ke- 47 dari 312
# mulai prediksi batch ke- 48 dari 312
# mulai prediksi batch ke- 49 dari 312
# mulai prediksi batch ke- 50 dari 312
# mulai prediksi batch ke- 51 dari 312
# mulai prediksi batch ke- 52 dari 312
# mulai prediksi batch ke- 53 dari 312
# mulai prediksi batch ke- 54 dari 312
# mulai prediksi batch ke- 55 dari 312
# mulai prediksi batch ke- 56 dari 312
# mulai prediksi batch ke- 57 dari 312
# mulai prediksi batch ke- 58 dari 312
# mulai prediksi batch ke- 59 dari 312
# mulai prediksi batch ke- 60 dari 312
# mulai prediksi batch ke- 61 dari 312
# mulai prediksi batch ke- 62 dari 312
# mulai prediksi batch ke- 63 dari 312
# mulai prediksi batch ke- 64 dari 312
# mulai prediksi batch ke- 65 dari 312
# mulai prediksi batch ke- 66 dari 312
# mulai prediksi batch ke- 67 dari 312
# mulai prediksi batch ke- 68 dari 312
# mulai prediksi batch ke- 69 dari 312
# mulai prediksi batch ke- 70 dari 312
# mulai prediksi batch ke- 71 dari 312
# mulai prediksi batch ke- 72 dari 312
# mulai prediksi batch ke- 73 dari 312
# mulai prediksi batch ke- 74 dari 312
# mulai prediksi batch ke- 75 dari 312
# mulai prediksi batch ke- 76 dari 312
# mulai prediksi batch ke- 77 dari 312
# mulai prediksi batch ke- 78 dari 312
# mulai prediksi batch ke- 79 dari 312
# mulai prediksi batch ke- 80 dari 312
# mulai prediksi batch ke- 81 dari 312
# mulai prediksi batch ke- 82 dari 312
# mulai prediksi batch ke- 83 dari 312
# mulai prediksi batch ke- 84 dari 312
# mulai prediksi batch ke- 85 dari 312
# mulai prediksi batch ke- 86 dari 312
# mulai prediksi batch ke- 87 dari 312
# mulai prediksi batch ke- 88 dari 312
# mulai prediksi batch ke- 89 dari 312
# mulai prediksi batch ke- 90 dari 312
# mulai prediksi batch ke- 91 dari 312
# mulai prediksi batch ke- 92 dari 312
# mulai prediksi batch ke- 93 dari 312
# mulai prediksi batch ke- 94 dari 312
# mulai prediksi batch ke- 95 dari 312
# mulai prediksi batch ke- 96 dari 312
# mulai prediksi batch ke- 97 dari 312
# mulai prediksi batch ke- 98 dari 312
# mulai prediksi batch ke- 99 dari 312
# mulai prediksi batch ke- 100 dari 312
# mulai prediksi batch ke- 101 dari 312
# mulai prediksi batch ke- 102 dari 312
# mulai prediksi batch ke- 103 dari 312
# mulai prediksi batch ke- 104 dari 312
# mulai prediksi batch ke- 105 dari 312
# mulai prediksi batch ke- 106 dari 312
# mulai prediksi batch ke- 107 dari 312
# mulai prediksi batch ke- 108 dari 312
# mulai prediksi batch ke- 109 dari 312
# mulai prediksi batch ke- 110 dari 312
# mulai prediksi batch ke- 111 dari 312
# mulai prediksi batch ke- 112 dari 312
# mulai prediksi batch ke- 113 dari 312
# mulai prediksi batch ke- 114 dari 312
# mulai prediksi batch ke- 115 dari 312
# mulai prediksi batch ke- 116 dari 312
# mulai prediksi batch ke- 117 dari 312
# mulai prediksi batch ke- 118 dari 312
# mulai prediksi batch ke- 119 dari 312
# mulai prediksi batch ke- 120 dari 312
# mulai prediksi batch ke- 121 dari 312
# mulai prediksi batch ke- 122 dari 312
# mulai prediksi batch ke- 123 dari 312
# mulai prediksi batch ke- 124 dari 312
# mulai prediksi batch ke- 125 dari 312
# mulai prediksi batch ke- 126 dari 312
# mulai prediksi batch ke- 127 dari 312
# mulai prediksi batch ke- 128 dari 312
# mulai prediksi batch ke- 129 dari 312
# mulai prediksi batch ke- 130 dari 312
# mulai prediksi batch ke- 131 dari 312
# mulai prediksi batch ke- 132 dari 312
# mulai prediksi batch ke- 133 dari 312
# mulai prediksi batch ke- 134 dari 312
# mulai prediksi batch ke- 135 dari 312
# mulai prediksi batch ke- 136 dari 312
# mulai prediksi batch ke- 137 dari 312
# mulai prediksi batch ke- 138 dari 312
# mulai prediksi batch ke- 139 dari 312
# mulai prediksi batch ke- 140 dari 312
# mulai prediksi batch ke- 141 dari 312
# mulai prediksi batch ke- 142 dari 312
# mulai prediksi batch ke- 143 dari 312
# mulai prediksi batch ke- 144 dari 312
# mulai prediksi batch ke- 145 dari 312
# mulai prediksi batch ke- 146 dari 312
# mulai prediksi batch ke- 147 dari 312
# mulai prediksi batch ke- 148 dari 312
# mulai prediksi batch ke- 149 dari 312
# mulai prediksi batch ke- 150 dari 312
# mulai prediksi batch ke- 151 dari 312
# mulai prediksi batch ke- 152 dari 312
# mulai prediksi batch ke- 153 dari 312
# mulai prediksi batch ke- 154 dari 312
# mulai prediksi batch ke- 155 dari 312
# mulai prediksi batch ke- 156 dari 312
# mulai prediksi batch ke- 157 dari 312
# mulai prediksi batch ke- 158 dari 312
# mulai prediksi batch ke- 159 dari 312
# mulai prediksi batch ke- 160 dari 312
# mulai prediksi batch ke- 161 dari 312
# mulai prediksi batch ke- 162 dari 312
# mulai prediksi batch ke- 163 dari 312
# mulai prediksi batch ke- 164 dari 312
# mulai prediksi batch ke- 165 dari 312
# mulai prediksi batch ke- 166 dari 312
# mulai prediksi batch ke- 167 dari 312
# mulai prediksi batch ke- 168 dari 312
# mulai prediksi batch ke- 169 dari 312
# mulai prediksi batch ke- 170 dari 312
# mulai prediksi batch ke- 171 dari 312
# mulai prediksi batch ke- 172 dari 312
# mulai prediksi batch ke- 173 dari 312
# mulai prediksi batch ke- 174 dari 312
# mulai prediksi batch ke- 175 dari 312
# mulai prediksi batch ke- 176 dari 312
# mulai prediksi batch ke- 177 dari 312
# mulai prediksi batch ke- 178 dari 312
# mulai prediksi batch ke- 179 dari 312
# mulai prediksi batch ke- 180 dari 312
# mulai prediksi batch ke- 181 dari 312
# mulai prediksi batch ke- 182 dari 312
# mulai prediksi batch ke- 183 dari 312
# mulai prediksi batch ke- 184 dari 312
# mulai prediksi batch ke- 185 dari 312
# mulai prediksi batch ke- 186 dari 312
# mulai prediksi batch ke- 187 dari 312
# mulai prediksi batch ke- 188 dari 312
# mulai prediksi batch ke- 189 dari 312
# mulai prediksi batch ke- 190 dari 312
# mulai prediksi batch ke- 191 dari 312
# mulai prediksi batch ke- 192 dari 312
# mulai prediksi batch ke- 193 dari 312
# mulai prediksi batch ke- 194 dari 312
# mulai prediksi batch ke- 195 dari 312
# mulai prediksi batch ke- 196 dari 312
# mulai prediksi batch ke- 197 dari 312
# mulai prediksi batch ke- 198 dari 312
# mulai prediksi batch ke- 199 dari 312
# mulai prediksi batch ke- 200 dari 312
# mulai prediksi batch ke- 201 dari 312
# mulai prediksi batch ke- 202 dari 312
# mulai prediksi batch ke- 203 dari 312
# mulai prediksi batch ke- 204 dari 312
# mulai prediksi batch ke- 205 dari 312
# mulai prediksi batch ke- 206 dari 312
# mulai prediksi batch ke- 207 dari 312
# mulai prediksi batch ke- 208 dari 312
# mulai prediksi batch ke- 209 dari 312
# mulai prediksi batch ke- 210 dari 312
# mulai prediksi batch ke- 211 dari 312
# mulai prediksi batch ke- 212 dari 312
# mulai prediksi batch ke- 213 dari 312
# mulai prediksi batch ke- 214 dari 312
# mulai prediksi batch ke- 215 dari 312
# mulai prediksi batch ke- 216 dari 312
# mulai prediksi batch ke- 217 dari 312
# mulai prediksi batch ke- 218 dari 312
# mulai prediksi batch ke- 219 dari 312
# mulai prediksi batch ke- 220 dari 312
# mulai prediksi batch ke- 221 dari 312
# mulai prediksi batch ke- 222 dari 312
# mulai prediksi batch ke- 223 dari 312
# mulai prediksi batch ke- 224 dari 312
# mulai prediksi batch ke- 225 dari 312
# mulai prediksi batch ke- 226 dari 312
# mulai prediksi batch ke- 227 dari 312
# mulai prediksi batch ke- 228 dari 312
# mulai prediksi batch ke- 229 dari 312
# mulai prediksi batch ke- 230 dari 312
# mulai prediksi batch ke- 231 dari 312
# mulai prediksi batch ke- 232 dari 312
# mulai prediksi batch ke- 233 dari 312
# mulai prediksi batch ke- 234 dari 312
# mulai prediksi batch ke- 235 dari 312
# mulai prediksi batch ke- 236 dari 312
# mulai prediksi batch ke- 237 dari 312
# mulai prediksi batch ke- 238 dari 312
# mulai prediksi batch ke- 239 dari 312
# mulai prediksi batch ke- 240 dari 312
# mulai prediksi batch ke- 241 dari 312
# mulai prediksi batch ke- 242 dari 312
# mulai prediksi batch ke- 243 dari 312
# mulai prediksi batch ke- 244 dari 312
# mulai prediksi batch ke- 245 dari 312
# mulai prediksi batch ke- 246 dari 312
# mulai prediksi batch ke- 247 dari 312
# mulai prediksi batch ke- 248 dari 312
# mulai prediksi batch ke- 249 dari 312
# mulai prediksi batch ke- 250 dari 312
# mulai prediksi batch ke- 251 dari 312
# mulai prediksi batch ke- 252 dari 312
# mulai prediksi batch ke- 253 dari 312
# mulai prediksi batch ke- 254 dari 312
# mulai prediksi batch ke- 255 dari 312
# mulai prediksi batch ke- 256 dari 312
# mulai prediksi batch ke- 257 dari 312
# mulai prediksi batch ke- 258 dari 312
# mulai prediksi batch ke- 259 dari 312
# mulai prediksi batch ke- 260 dari 312
# mulai prediksi batch ke- 261 dari 312
# mulai prediksi batch ke- 262 dari 312
# mulai prediksi batch ke- 263 dari 312
# mulai prediksi batch ke- 264 dari 312
# mulai prediksi batch ke- 265 dari 312
# mulai prediksi batch ke- 266 dari 312
# mulai prediksi batch ke- 267 dari 312
# mulai prediksi batch ke- 268 dari 312
# mulai prediksi batch ke- 269 dari 312
# mulai prediksi batch ke- 270 dari 312
# mulai prediksi batch ke- 271 dari 312
# mulai prediksi batch ke- 272 dari 312
# mulai prediksi batch ke- 273 dari 312
# mulai prediksi batch ke- 274 dari 312
# mulai prediksi batch ke- 275 dari 312
# mulai prediksi batch ke- 276 dari 312
# mulai prediksi batch ke- 277 dari 312
# mulai prediksi batch ke- 278 dari 312
# mulai prediksi batch ke- 279 dari 312
# mulai prediksi batch ke- 280 dari 312
# mulai prediksi batch ke- 281 dari 312
# mulai prediksi batch ke- 282 dari 312
# mulai prediksi batch ke- 283 dari 312
# mulai prediksi batch ke- 284 dari 312
# mulai prediksi batch ke- 285 dari 312
# mulai prediksi batch ke- 286 dari 312
# mulai prediksi batch ke- 287 dari 312
# mulai prediksi batch ke- 288 dari 312
# mulai prediksi batch ke- 289 dari 312
# mulai prediksi batch ke- 290 dari 312
# mulai prediksi batch ke- 291 dari 312
# mulai prediksi batch ke- 292 dari 312
# mulai prediksi batch ke- 293 dari 312
# mulai prediksi batch ke- 294 dari 312
# mulai prediksi batch ke- 295 dari 312
# mulai prediksi batch ke- 296 dari 312
# mulai prediksi batch ke- 297 dari 312
# mulai prediksi batch ke- 298 dari 312
# mulai prediksi batch ke- 299 dari 312
# mulai prediksi batch ke- 300 dari 312
# mulai prediksi batch ke- 301 dari 312
# mulai prediksi batch ke- 302 dari 312
# mulai prediksi batch ke- 303 dari 312
# mulai prediksi batch ke- 304 dari 312
# mulai prediksi batch ke- 305 dari 312
# mulai prediksi batch ke- 306 dari 312
# mulai prediksi batch ke- 307 dari 312
# mulai prediksi batch ke- 308 dari 312
# mulai prediksi batch ke- 309 dari 312
# mulai prediksi batch ke- 310 dari 312
# mulai prediksi batch ke- 311 dari 312
# mulai prediksi batch ke- 312 dari 312

# %%
print("Macro F1-Score on Test Set:", accuracy1)
print("Macro F1-Score on Test Set:", accuracy2)
print("Macro F1-Score on Test Set:", accuracy3)
# Out:
# Macro F1-Score on Test Set: 0.14648750545247657
# Macro F1-Score on Test Set: 0.47086888925546366
# Macro F1-Score on Test Set: 0.23728632309578906
